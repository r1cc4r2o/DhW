# %%
# !pip install librosa
# Out:
# Collecting librosa
#   Downloading librosa-0.10.0.post2-py3-none-any.whl (253 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 5.3 MB/s eta 0:00:00a 0:00:01
# Collecting audioread>=2.1.9 (from librosa)
#   Downloading audioread-3.0.0.tar.gz (377 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 kB 17.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /home/rickbook/mambaforge/envs/uri_mne/lib/python3.9/site-packages (from librosa) (1.24.3)
# Requirement already satisfied: scipy>=1.2.0 in /home/rickbook/mambaforge/envs/uri_mne/lib/python3.9/site-packages (from librosa) (1.9.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /home/rickbook/mambaforge/envs/uri_mne/lib/python3.9/site-packages (from librosa) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /home/rickbook/mambaforge/envs/uri_mne/lib/python3.9/site-packages (from librosa) (1.2.0)
# Requirement already satisfied: decorator>=4.3.0 in /home/rickbook/mambaforge/envs/uri_mne/lib/python3.9/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /home/rickbook/mambaforge/envs/uri_mne/lib/python3.9/site-packages (from librosa) (0.57.0)
# Collecting soundfile>=0.12.1 (from librosa)
#   Downloading soundfile-0.12.1-py2.py3-none-manylinux_2_31_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 33.6 MB/s eta 0:00:0000:01
# Collecting pooch<1.7,>=1.0 (from librosa)
#   Downloading pooch-1.6.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 12.2 MB/s eta 0:00:00
# Collecting soxr>=0.3.2 (from librosa)
#   Downloading soxr-0.3.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 10.8 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: typing-extensions>=4.1.1 in /home/rickbook/mambaforge/envs/uri_mne/lib/python3.9/site-packages (from librosa) (4.6.3)
# Requirement already satisfied: lazy-loader>=0.1 in /home/rickbook/mambaforge/envs/uri_mne/lib/python3.9/site-packages (from librosa) (0.2)
# Collecting msgpack>=1.0 (from librosa)
#   Downloading msgpack-1.0.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (322 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 kB 39.2 MB/s eta 0:00:00
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /home/rickbook/mambaforge/envs/uri_mne/lib/python3.9/site-packages (from numba>=0.51.0->librosa) (0.40.0)
# Collecting appdirs>=1.3.0 (from pooch<1.7,>=1.0->librosa)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: packaging>=20.0 in /home/rickbook/mambaforge/envs/uri_mne/lib/python3.9/site-packages (from pooch<1.7,>=1.0->librosa) (23.1)
# Requirement already satisfied: requests>=2.19.0 in /home/rickbook/mambaforge/envs/uri_mne/lib/python3.9/site-packages (from pooch<1.7,>=1.0->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/rickbook/mambaforge/envs/uri_mne/lib/python3.9/site-packages (from scikit-learn>=0.20.0->librosa) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /home/rickbook/mambaforge/envs/uri_mne/lib/python3.9/site-packages (from soundfile>=0.12.1->librosa) (1.15.1)
# Requirement already satisfied: pycparser in /home/rickbook/mambaforge/envs/uri_mne/lib/python3.9/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/rickbook/mambaforge/envs/uri_mne/lib/python3.9/site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/rickbook/mambaforge/envs/uri_mne/lib/python3.9/site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/rickbook/mambaforge/envs/uri_mne/lib/python3.9/site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/rickbook/mambaforge/envs/uri_mne/lib/python3.9/site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (2023.5.7)
# Building wheels for collected packages: audioread
#   Building wheel for audioread (setup.py) ... done
#   Created wheel for audioread: filename=audioread-3.0.0-py3-none-any.whl size=23706 sha256=56a5e922fa28eebfeac4ebd627fe05464c27d579fd45118838c8bdc6a0045684
#   Stored in directory: /home/rickbook/.cache/pip/wheels/e4/76/a4/cfb55573167a1f5bde7d7a348e95e509c64b2c3e8f921932c3
# Successfully built audioread
# Installing collected packages: msgpack, appdirs, soxr, audioread, soundfile, pooch, librosa
#   Attempting uninstall: pooch
#     Found existing installation: pooch 1.7.0
#     Uninstalling pooch-1.7.0:
#       Successfully uninstalled pooch-1.7.0
# Successfully installed appdirs-1.4.4 audioread-3.0.0 librosa-0.10.0.post2 msgpack-1.0.5 pooch-1.6.0 soundfile-0.12.1 soxr-0.3.5

# %%
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
# %matplotlib inline


# this is the number of samples in a window per fft
n_fft = 2048
# The amount of samples we are shifting after each fft
hop_length = 512


# Load an example with vocals.
signal, sr = librosa.load(librosa.util.example("brahms"))

mel_signal = librosa.feature.melspectrogram(y=signal, sr=sr, hop_length=hop_length, 
 n_fft=n_fft)
spectrogram = np.abs(mel_signal)
power_to_db = librosa.power_to_db(spectrogram, ref=np.max)


plt.figure(figsize=(7, 16))
librosa.display.specshow(power_to_db, sr=sr, cmap="magma", 
 hop_length=hop_length) # x_axis=’time’, y_axis=’mel’

plt.colorbar(label="dB")
plt.title('Mel-Spectrogram (dB)', fontdict=dict(size=18))
plt.xlabel('Time', fontdict=dict(size=15))
plt.ylabel('Frequency', fontdict=dict(size=15))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 27
#      23 plt.figure(figsize=(7, 16))
#      24 librosa.display.specshow(power_to_db, sr=sr, cmap="magma",
#      25  hop_length=hop_length) # x_axis=’time’, y_axis=’mel’
# ---> 27 plt.colorbar(label="dB")
#      28 plt.title('Mel-Spectrogram (dB)', fontdict=dict(size=18))
#      29 plt.xlabel('Time', fontdict=dict(size=15))
#
# File ~/mambaforge/envs/uri_mne/lib/python3.9/site-packages/matplotlib/pyplot.py:2137, in colorbar(mappable, cax, ax, **kwargs)
#    2132     if mappable is None:
#    2133         raise RuntimeError('No mappable was found to use for colorbar '
#    2134                            'creation. First define a mappable such as '
#    2135                            'an image (with imshow) or a contour set ('
#    2136                            'with contourf).')
# -> 2137 ret = gcf().colorbar(mappable, cax=cax, ax=ax, **kwargs)
#    2138 return ret
#
# File ~/mambaforge/envs/uri_mne/lib/python3.9/site-packages/matplotlib/figure.py:1279, in FigureBase.colorbar(self, mappable, cax, ax, use_gridspec, **kwargs)
#    1276 current_ax = self.gca()
#    1277 userax = False
#    1278 if (use_gridspec
# -> 1279         and isinstance(ax, mpl.axes._base._AxesBase)
#    1280         and ax.get_subplotspec()):
#    1281     cax, kwargs = cbar.make_axes_gridspec(ax, **kwargs)
#    1282 else:
#
# File ~/mambaforge/envs/uri_mne/lib/python3.9/site-packages/matplotlib/_api/__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'axes'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/mambaforge/envs/uri_mne/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:99, in show(close, block)
#      96 # only call close('all') if any to close
#      97 # close triggers gc.collect, which can be slow
#      98 if close and Gcf.get_all_fig_managers():
# ---> 99     matplotlib.pyplot.close('all')
#
# File ~/mambaforge/envs/uri_mne/lib/python3.9/site-packages/matplotlib/_api/__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'pyplot'

# %%
log_S.shape
# Out:
# (128, 1)
